# %% [markdown]
# <a href="https://colab.research.google.com/github/rodgpt/MAR_FUTURA/blob/Optimization-but-with-NDSI-package/NDSI/NDSI_Sites_Comparisson_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This code compares the NDSI and bio-anthro energy for different cases. It allows to set a date range

# %% [markdown]
# This notebook is structured to run on Google Colab using a Python runtime with R via rpy2.
# Three changes to run locally vs run in colab:
# 1. Remove the from google.colab import drive line
# 2. Remove the drive.mount("/content/gdrive") line
# 3. Change the path to the data folder in the third cell

# %%
#This cell mounts the google drive and install packages to be able to run the rest in R, because the whole runtime is in phyton

#Just for google colab
#from google.colab import drive
#drive.mount('/content/drive')

# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# Requirement already satisfied: rpy2 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (3.6.4)
# Requirement already satisfied: rpy2-rinterface>=3.6.3 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from rpy2) (3.6.3)
# Requirement already satisfied: rpy2-robjects>=3.6.3 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from rpy2) (3.6.3)
# Requirement already satisfied: cffi>=1.15.1 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from rpy2-rinterface>=3.6.3->rpy2) (2.0.0)
# Requirement already satisfied: pycparser in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from cffi>=1.15.1->rpy2-rinterface>=3.6.3->rpy2) (2.23)
# Requirement already satisfied: jinja2 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from rpy2-robjects>=3.6.3->rpy2) (3.1.6)
# Requirement already satisfied: tzlocal in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from rpy2-robjects>=3.6.3->rpy2) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages (from jinja2->rpy2-robjects>=3.6.3->rpy2) (3.0.3)
# Error importing in API mode: ImportError("dlopen(/Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages/_rinterface_cffi_api.abi3.so, 0x0002): Library not loaded: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib\n  Referenced from: <08761B8B-0767-3CA6-9437-5468D1CD700F> /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages/_rinterface_cffi_api.abi3.so\n  Reason: tried: '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file)")
# Trying to import in ABI mode.
# /Users/rodrigo/Desktop/CODES/.venv/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:96: UserWarning: The Python package `pandas` is strongly recommended when using `rpy2.ipython`. Unfortunately it could not be loaded, as we did not manage to load `numpy` in the first place (error: No module named 'numpy').
#   warnings.warn('The Python package `pandas` is strongly '

# %%
# %%R
#
# install.packages("tuneR")
# install.packages("seewave")
# install.packages("dplyr")
# install.packages("purrr")
# install.packages("ggplot2")
# install.packages("scales")
# install.packages("lubridate")
# install.packages("tidyr")
# install.packages("soundecology")
# install.packages("beepr")
# install.packages("future")
# install.packages("future.apply")
#
# library(tuneR)
# library(seewave)
# library(dplyr)
# library(purrr)
# library(ggplot2)
# library(scales)
# library(lubridate)
# library(tidyr)
# library(soundecology)
# library(beepr)
# library(future)
# library(future.apply)

# %%
# %%R
#
# ##For running locally (Rod)
# dirs_sites <- list(
#   "San Antonio 38" = "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/San Antonio/12-11-25/38",
#   "Ventanas 36" = "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Ventanas/07-11-25/36",
#   "Zapallar 34" = "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Zapallar/07-11-25/34",
#   "Las Cruces 26" = "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/LasCruces/12-11-25/26",
#   "Matanzas 32" = "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Matanzas/13-11-25/32"
# )
# output_dir <- "/Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/NDSIResults"
#
# ##For running in Colab
# #dirs_sites <- list(
#  # "San Antonio 38" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/San Antonio/12-11-25/38", ### este esta mal. En GD lo tengo como 38 en san antonio, pero enverdad no se que es
#  # "Ventanas 36" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Ventanas/07-11-25/36",       ### esta esta bien
#   #"Zapallar 34" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Zapallar/07-11-25/34",       ### esta esta bien
#   #"Las Cruces 26" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/LasCruces/12-11-25/26",    ### este esta mal. En GD lo tengo como 26 en las cruces, pero enverdad es san antonio
#   #"Matanzas 32" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Matanzas/13-11-25/32"        ### este esta bien.
# #)
#
# #output_dir <- "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/NDSIResults"
#
# segment_sec <- 60
# anthro_band <- c(1000, 2000)
# bio_band    <- c(2000, 3000) #c(2000, 3000)
# tz <- "UTC"
# analysis_duration <- NA
# files_per_folder <- NA
# files_per_hour <- 4
# output_csv <- "ndsi_casestudies_results.csv"
#
# start_date <- as.POSIXct("2025-11-21 00:00:00", tz = tz)
# end_date   <- as.POSIXct("2025-11-24 23:59:59", tz = tz)
#
# workers <- max(1, parallel::detectCores() - 1)
# future::plan(future::multisession, workers = workers)
#
# extract_datetime <- function(filename) {
#   dt_str <- sub("^(?:ST_\\d+_)?(\\d{8}_\\d{6})\\.WAV$", "\\1", basename(filename), ignore.case = TRUE)
#   as.POSIXct(dt_str, format = "%Y%m%d_%H%M%S", tz = tz)
# }
#
# calculate_ndsi <- function(wave_obj) {
#   nd <- NULL
#   suppressWarnings(suppressMessages(invisible(capture.output({
#     nd <- soundecology::ndsi(
#       wave_obj,
#       anthro_min = anthro_band[1], anthro_max = anthro_band[2],
#       bio_min    = bio_band[1],    bio_max    = bio_band[2]
#     )
#   }))))
#
#   list(
#     ndsi = nd$ndsi_left,
#     anthro_energy = NA_real_,
#     bio_energy = NA_real_
#   )
# }
#
# .evenly_spaced_indices <- function(n, k) {
#   if (k <= 0) return(integer(0))
#   if (n <= k) return(seq_len(n))
#   idx <- round((seq_len(k) * (n + 1)) / (k + 1))
#   idx <- pmax(1L, pmin(n, idx))
#   sort(unique(idx))
# }
#
# .fmt_secs <- function(secs) {
#   if (!is.finite(secs) || is.na(secs) || secs < 0) return("NA")
#   secs <- as.integer(round(secs))
#   h <- secs %/% 3600
#   m <- (secs %% 3600) %/% 60
#   s <- secs %% 60
#   if (h > 0) return(sprintf("%dh%02dm%02ds", h, m, s))
#   if (m > 0) return(sprintf("%dm%02ds", m, s))
#   sprintf("%ds", s)
# }
#
# .in_notebook <- function() {
#   nzchar(Sys.getenv("JPY_PARENT_PID")) ||
#     nzchar(Sys.getenv("COLAB_GPU")) ||
#     nzchar(Sys.getenv("COLAB_RELEASE_TAG"))
# }
#
# process_site <- function(directory, label) {
#   files <- list.files(directory, pattern = "\\.wav$", full.names = TRUE, recursive = TRUE, ignore.case = TRUE)
#   message("Found ", length(files), " files in ", label, " (searching recursively, case-insensitive)")
#
#   if (length(files) == 0) {
#     return(tibble(
#       Site = character(),
#       Time = as.POSIXct(character()),
#       NDSI = numeric(),
#       Anthro_Energy = numeric(),
#       Bio_Energy = numeric()
#     ))
#   }
#
#   files <- sort(files)
#
#   if (!is.na(files_per_hour) && (is.na(files_per_hour) || files_per_hour <= 0)) {
#     stop("`files_per_hour` must be NA or a positive number.")
#   }
#
#   file_dt <- purrr::map_df(files, ~tibble(
#     filepath = .x,
#     start_dt = extract_datetime(.x)
#   ))
#
#   if (nrow(file_dt) > 0) {
#     if (!is.na(start_date)) {
#       file_dt <- dplyr::filter(file_dt, start_dt >= (start_date - segment_sec))
#     }
#     if (!is.na(end_date)) {
#       file_dt <- dplyr::filter(file_dt, start_dt <= end_date)
#     }
#   }
#
#   file_dt <- dplyr::arrange(file_dt, start_dt)
#
#   if (!is.na(files_per_hour)) {
#     k <- as.integer(files_per_hour)
#     file_dt <- file_dt %>%
#       mutate(.hour = lubridate::floor_date(start_dt, unit = "hour")) %>%
#       group_by(.hour) %>%
#       arrange(start_dt, .by_group = TRUE) %>%
#       group_modify(function(.x, .g) {
#         idx <- .evenly_spaced_indices(nrow(.x), k)
#         .x[idx, , drop = FALSE]
#       }) %>%
#       ungroup() %>%
#       select(-.hour)
#   }
#
#   files <- file_dt$filepath
#
#   if (!is.na(files_per_folder)) {
#     files <- head(files, files_per_folder)
#   }
#
#   if (length(files) == 0) {
#     return(tibble(
#       Site = character(),
#       Time = as.POSIXct(character()),
#       NDSI = numeric(),
#       Anthro_Energy = numeric(),
#       Bio_Energy = numeric()
#     ))
#   }
#
#   pb <- utils::txtProgressBar(min = 0, max = length(files), style = 3)
#   on.exit({
#     try(close(pb), silent = TRUE)
#   }, add = TRUE)
#
#   t0 <- Sys.time()
#   last_print <- Sys.time()
#
#   results <- vector("list", length(files))
#   out_k <- 0L
#
#   for (i in seq_along(files)) {
#     fp <- files[[i]]
#
#     utils::setTxtProgressBar(pb, i)
#     flush.console()
#
#     now <- Sys.time()
#     if (i == 1L || i == length(files) || as.numeric(difftime(now, last_print, units = "secs")) >= 2) {
#       elapsed <- as.numeric(difftime(now, t0, units = "secs"))
#       avg_sec <- elapsed / i
#       remaining <- avg_sec * (length(files) - i)
#       pct <- 100 * i / length(files)
#       eta <- now + remaining
#
#       cat(sprintf(
#         "%s | %5.1f%% | %d/%d | avg %s/file | ETA %s | ~%s remaining\\n",
#         label,
#         pct,
#         i,
#         length(files),
#         .fmt_secs(avg_sec),
#         format(eta, "%H:%M:%S"),
#         .fmt_secs(remaining)
#       ))
#       flush.console()
#
#       last_print <- now
#     }
#
#     start_dt <- extract_datetime(fp)
#
#     wav <- tryCatch(readWave(fp), error = function(e) {
#       warning("Skipping unreadable file: ", fp)
#       return(NULL)
#     })
#     if (is.null(wav)) next
#
#     dur_sec <- length(wav@left) / wav@samp.rate
#     seg_len <- min(segment_sec, dur_sec)
#     if (!is.finite(seg_len) || seg_len <= 0) next
#
#     max_start <- max(0, dur_sec - seg_len)
#     starts <- seq(0, max_start, by = seg_len)
#
#     for (st in starts) {
#       segment_time <- start_dt + st
#
#       if (!is.na(start_date) && segment_time < start_date) {
#         next
#       }
#       if (!is.na(end_date) && segment_time > end_date) {
#         break
#       }
#
#       seg <- tryCatch(
#         extractWave(wav, from = st, to = st + seg_len, xunit = "time"),
#         error = function(e) return(NULL)
#       )
#       if (is.null(seg)) next
#
#       ndsi_res <- calculate_ndsi(seg)
#
#       out_k <- out_k + 1L
#       results[[out_k]] <- tibble(
#         Site = label,
#         Time = segment_time,
#         NDSI = ndsi_res$ndsi,
#         Anthro_Energy = ndsi_res$anthro_energy,
#         Bio_Energy = ndsi_res$bio_energy
#       )
#     }
#   }
#
#   cat("\\n")
#
#   if (out_k == 0L) {
#     return(tibble(
#       Site = character(),
#       Time = as.POSIXct(character()),
#       NDSI = numeric(),
#       Anthro_Energy = numeric(),
#       Bio_Energy = numeric()
#     ))
#   }
#
#   bind_rows(results[seq_len(out_k)])
# }
#
# anthro_tag <- paste0("anthro_", anthro_band[1], "-", anthro_band[2])
# bio_tag <- paste0("bio_", bio_band[1], "-", bio_band[2])
#
# date_tag <- if (!is.na(start_date) && !is.na(end_date)) {
#   paste0(format(start_date, "%Y%m%d"), "-", format(end_date, "%Y%m%d"))
# } else {
#   "alltime"
# }
#
# dir.create(output_dir, recursive = TRUE, showWarnings = FALSE)
#
# all_results_list <- list()
#
# for (label in names(dirs_sites)) {
#   res <- tryCatch(
#     process_site(dirs_sites[[label]], label),
#     error = function(e) {
#       warning("Site failed: ", label, " - ", conditionMessage(e))
#       return(tibble(
#         Site = character(),
#         Time = as.POSIXct(character()),
#         NDSI = numeric(),
#         Anthro_Energy = numeric(),
#         Bio_Energy = numeric()
#       ))
#     }
#   )
#   all_results_list[[label]] <- res
# }
#
# all_results <- bind_rows(all_results_list)
#
# if (!exists("all_results") || nrow(all_results) == 0) {
#   stop("No WAV files found in the provided directories and date range. Please verify the paths in `dirs_sites` and the date filters.")
# }
#
# output_csv_all <- file.path(output_dir, paste0(
#   "ndsi_casestudies_", date_tag, "_", anthro_tag, "_", bio_tag, ".csv"
# ))
# write.csv(all_results, output_csv_all, row.names = FALSE)
# message("Saved to: ", output_csv_all)
#
# summary_stats <- all_results %>%
#   group_by(Site) %>%
#   summarize(
#     Segments  = n(),
#     Mean_NDSI = mean(NDSI, na.rm = TRUE),
#     SD_NDSI   = sd(NDSI, na.rm = TRUE)
#   )
# print(summary_stats)
#
# plot_data <- all_results
#
# plot_data$Site <- factor(plot_data$Site, levels = names(dirs_sites))
#
# ## NDSI time-series plot
# p_ndsi <- ggplot(plot_data, aes(x = Time, y = NDSI, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "NDSI Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "NDSI"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_ndsi)
#
# ## NDSI quadrant table (percentage of time per site in each quadrant)
# ndsi_quadrant_table <- plot_data %>%
#   mutate(
#     NDSI_Quadrant = case_when(
#       NDSI >= 0.5  & NDSI <= 1   ~ "[0.5, 1]",
#       NDSI >  0    & NDSI <  0.5 ~ "(0, 0.5)",
#       NDSI >= -0.5 & NDSI <= 0   ~ "[-0.5, 0]",
#       NDSI >= -1   & NDSI < -0.5 ~ "[-1, -0.5)",
#       TRUE ~ NA_character_
#     )
#   ) %>%
#   filter(!is.na(NDSI_Quadrant)) %>%
#   group_by(Site, NDSI_Quadrant) %>%
#   summarise(
#     Segments = n(),
#     .groups = "drop_last"
#   ) %>%
#   mutate(
#     Total_Segments = sum(Segments),
#     Percent_Time = 100 * Segments / Total_Segments
#   ) %>%
#   ungroup()
#
# print(ndsi_quadrant_table)
#
# beepr::beep(3)
# Out:
#   |======================================================================| 100%San Antonio 38 |   0.3% | 1/384 | avg 0s/file | ETA 21:32:33 | ~0s remaining\nSan Antonio 38 |   0.8% | 3/384 | avg 1s/file | ETA 21:40:30 | ~7m53s remaining\nSan Antonio 38 |   1.0% | 4/384 | avg 1s/file | ETA 21:41:46 | ~9m07s remaining\nSan Antonio 38 |   1.6% | 6/384 | avg 2s/file | ETA 21:42:37 | ~9m55s remaining\nSan Antonio 38 |   2.1% | 8/384 | avg 2s/file | ETA 21:42:58 | ~10m12s remaining\nSan Antonio 38 |   2.6% | 10/384 | avg 2s/file | ETA 21:43:26 | ~10m36s remaining\nSan Antonio 38 |   2.9% | 11/384 | avg 2s/file | ETA 21:43:38 | ~10m46s remaining\nSan Antonio 38 |   3.4% | 13/384 | avg 2s/file | ETA 21:43:45 | ~10m49s remaining\nSan Antonio 38 |   3.9% | 15/384 | avg 2s/file | ETA 21:43:50 | ~10m50s remaining\nSan Antonio 38 |   4.4% | 17/384 | avg 2s/file | ETA 21:43:53 | ~10m50s remaining\nSan Antonio 38 |   4.9% | 19/384 | avg 2s/file | ETA 21:43:57 | ~10m50s remaining\nSan Antonio 38 |   5.5% | 21/384 | avg 2s/file | ETA 21:44:05 | ~10m54s remaining\nSan Antonio 38 |   6.0% | 23/384 | avg 2s/file | ETA 21:44:08 | ~10m53s remaining\nSan Antonio 38 |   6.5% | 25/384 | avg 2s/file | ETA 21:44:10 | ~10m51s remaining\nSan Antonio 38 |   7.0% | 27/384 | avg 2s/file | ETA 21:44:12 | ~10m49s remaining\nSan Antonio 38 |   7.6% | 29/384 | avg 2s/file | ETA 21:44:14 | ~10
10m40s remaining\nVentanas 36 |  13.5% | 52/384 | avg 2s/file | ETA 21:57:10 | ~10m38s remaining\nVentanas 36 |  13.8% | 53/384 | avg 2s/file | ETA 21:57:11 | ~10m36s remaining\nVentanas 36 |  14.3% | 55/384 | avg 2s/file | ETA 21:57:12 | ~10m33s remaining\nVentanas 36 |  14.8% | 57/384 | avg 2s/file | ETA 21:57:12 | ~10m29s remaining\nVentanas 36 |  15.1% | 58/384 | avg 2s/file | ETA 21:57:12 | ~10m28s remaining\nVentanas 36 |  15.6% | 60/384 | avg 2s/file | ETA 21:57:12 | ~10m24s remaining\nVentanas 36 |  16.1% | 62/384 | avg 2s/file | ETA 21:57:13 | ~10m20s remaining\nVentanas 36 |  16.7% | 64/384 | avg 2s/file | ETA 21:57:11 | ~10m15s remaining\nVentanas 36 |  17.2% | 66/384 | avg 2s/file | ETA 21:57:11 | ~10m11s remaining\nVentanas 36 |  17.7% | 68/384 | avg 2s/file | ETA 21:57:11 | ~10m07s remaining\nVentanas 36 |  18.2% | 70/384 | avg 2s/file | ETA 21:57:11 | ~10m03s remaining\nVentanas 36 |  18.5% | 71/384 | avg 2s/file | ETA 21:57:12 | ~10m02s remaining\nVentanas 36 |  19.0% | 73/384 | avg 2s/file | ETA 21:57:12 | ~9m58s remaining\nVentanas 36 |  19.5% | 75/384 | avg 2s/file | ETA 21:57:11 | ~9m54s remaining\nVentanas 36 |  20.1% | 77/384 | avg 2s/file | ETA 21:57:11 | ~9m50s remaining\nVentanas 36 |  20.3% | 78/384 | avg 2s/file | ETA 21:57:12 | ~9m49s remaining\nVentanas 36 |  20.6% | 79/384 | avg 2s/file | ETA 21:57:12 | ~9m47s remaining\nVentanas 36 |  21.1% | 81/384 | avg 2s/file | ETA 21:57:11 | ~9m43s remaining\nVentanas 36 |  21.6% | 83/384 | avg 2s/file | ETA 21:57:11 | ~9m39s remaining\nVentanas 36 |  22.1% | 85/384 | avg 2s/file | ETA 21:57:11 | ~9m35s remaining\nVentanas 36 |  22.4% ...
#   |======================================================================| 100%Zapallar 34 |   0.3% | 1/384 | avg 0s/file | ETA 21:57:18 | ~0s remaining\nZapallar 34 |   0.8% | 3/384 | avg 1s/file | ETA 22:05:27 | ~8m06s remaining\nZapallar 34 |   1.0% | 4/384 | avg 1s/file | ETA 22:06:40 | ~9m16s remaining\nZapallar 34 |   1.3% | 5/384 | avg 2s/file | ETA 22:07:24 | ~9m58s remaining\nZapallar 34 |   1.8% | 7/384 | avg 2s/file | ETA 22:07:56 | ~10m26s remaining\nZapallar 34 |   2.3% | 9/384 | avg 2s/file | ETA 22:08:21 | ~10m48s remaining\nZapallar 34 |   2.9% | 11/384 | avg 2s/file | ETA 22:08:37 | ~10m59s remaining\nZapallar 34 |   3.4% | 13/384 | avg 2s/file | ETA 22:08:45 | ~11m03s remaining\nZapallar 34 |   3.9% | 15/384 | avg 2s/file | ETA 22:08:47 | ~11m02s remaining\nZapallar 34 |   4.4% | 17/384 | avg 2s/file | ETA 22:08:53 | ~11m04s remaining\nZapallar 34 |   4.9% | 19/384 | avg 2s/file | ETA 22:08:59 | ~11m07s remaining\nZapallar 34 |   5.5% | 21/384 | avg 2s/file | ETA 22:09:00 | ~11m03s remaining\nZapallar 34 |   6.0% | 23/384 | avg 2s/file | ETA 22:09:00 | ~11m00s remaining\nZapallar 34 |   6.5% | 25/384 | avg 2s/file | ETA 22:09:03 | ~10m59s remaining\nZapallar 34 |   7.0% | 27/384 | avg 2s/file | ETA 22:09:05 | ~10m58s remaining\nZapallar 34 |   7.6% | 29/384 | avg 2s/file | ETA 22:09:08 | ~10m57s remaining\nZapallar 34 |   8.1% | 31/384 | avg 2s/file | ETA 22:09:11 | ~10m55s remaining\nZapallar 34 |   8.6% | 33/384 | avg 2s/file | ETA 22:09:08 | ~10m49s remaining\nZapallar 34 |   9.1% | 35/384 | avg 2s/file | ETA 22:09:09 | ~10m46s remaining\nZapallar 34 |   9.6% | 37/384 | avg 2s/file | ETA 22:09:08 | ~10m42s remaining\nZapallar 34 |  10.2% | 39/384 | avg 2s/file | ETA 22:09:08 | ~10m38s remaining\nZapallar 34 |  10.7% | 41/384 | avg 2s/file | ETA 22:09:09 | ~10m35s remaining\nZapallar 34 |  11.2% | 43/384 | avg 2s/file | ETA 22:09:10 | ~10m33s remaining\nZapallar 34 |  11.7% | 45/384 | avg 2s/file | ETA 22:09:12 | ~10m30s remaining\nZapallar 34 |  12.2% | 47/384 | avg 2s/file | ETA 22:09:12 | ~10m27s remaining\nZapallar 34 |  12.8% | 49/384 | avg 2s/file | ETA 22:09:11 | ~10m22s remaining\nZapallar 34 |  13.3% | 51/384 | avg 2s/file | ETA 22:09:14 | ~10m20s remaining\nZapallar 34 |  13.8% | 53/384 | avg 2s/file | ETA 22:09:14 | ~10m17s remaining\nZapallar 34 |  14.1% | 54/384 | avg 2s/file | ETA 22:09:15 | ~10m16s remaining\nZapallar 34 |  14.6% | 56/384 | avg 2s/file | ETA 22:09:16 | ~10m13s remaining\nZapallar 34 |  14.8% | 57/384 | avg 2s/file | ETA 22:09:17 | ~10m12s remaining\nZapallar 34 |  15.4% | 59/384 | avg 2s/file | ETA 22:09:18 | ~10m09s remaining\nZapallar 34 |  15.9% | 61/384 | avg 2s/file | ETA 22:09:19 | ~10m07s remaining\nZapallar 34 |  16.4% | 63/384 | avg 2s/file | ETA 22:09:20 | ~10m03s remaining\nZapallar 34 |  16.9% | 65/384 | avg 2s/file | ETA 22:09:19 | ~9m59s remaining\nZapallar 34 |  17.4% | 67/384 | avg 2s/file | ETA 22:09:20 | ~9m56s remaining\nZapallar 34 |  17.7% | 68/384 | avg 2s/file | ETA 22:09:21 | ~9m55s remaining\nZapallar 34 |  18.2% | 70/384 | avg 2s/file | ETA 22:09:21 | ~9m51s remaining\nZapallar 34 |  18.8% | 72/384 | avg 2s/file | ETA 22:09:20 | ~9m47s remaining\nZapallar 34 |  19.3% | 74/384 | avg 2s/file | ETA 22:09:20 | ~9m43s remaining\nZapallar 34 |  19.8% | 76/384 | avg 2s/file | ETA 22:09:21 | ~9m40s remaining\nZapallar 34 |  20.3% | 78/384 |
#   |======================================================================| 100%Matanzas 32 |   0.3% | 1/384 | avg 0s/file | ETA 22:22:01 | ~0s remaining\nMatanzas 32 |   0.8% | 3/384 | avg 1s/file | ETA 22:30:51 | ~8m46s remaining\nMatanzas 32 |   1.3% | 5/384 | avg 2s/file | ETA 22:32:00 | ~9m52s remaining\nMatanzas 32 |   1.8% | 7/384 | avg 2s/file | ETA 22:32:41 | ~10m28s remaining\nMatanzas 32 |   2.3% | 9/384 | avg 2s/file | ETA 22:32:50 | ~10m34s remaining\nMatanzas 32 |   2.9% | 11/384 | avg 2s/file | ETA 22:33:07 | ~10m47s remaining\nMatanzas 32 |   3.1% | 12/384 | avg 2s/file | ETA 22:33:17 | ~10m55s remaining\nMatanzas 32 |   3.6% | 14/384 | avg 2s/file | ETA 22:33:27 | ~11m01s remaining\nMatanzas 32 |   4.2% | 16/384 | avg 2s/file | ETA 22:33:32 | ~11m02s remaining\nMatanzas 32 |   4.4% | 17/384 | avg 2s/file | ETA 22:33:40 | ~11m08s remaining\nMatanzas 32 |   4.7% | 18/384 | avg 2s/file | ETA 22:33:45 | ~11m11s remaining\nMatanzas 32 |   5.2% | 20/384 | avg 2s/file | ETA 22:33:47 | ~11m10s remaining\nMatanzas 32 |   5.7% | 22/384 | avg 2s/file | ETA 22:33:51 | ~11m09s remaining\nMatanzas 32 |   6.2% | 24/384 | avg 2s/file | ETA 22:33:50 | ~11m04s remaining\nMatanzas 32 |   6.5% | 25/384 | avg 2s/file | ETA 22:33:52 | ~11m05s remaining\nMatanzas 32 |   7.0% | 27/384 | avg 2s/file | ETA 22:33:53 | ~11m02s remaining\nMatanzas 32 |   7.6% | 29/384 | avg 2s/file | ETA 22:33:56 | ~11m01s remaining\nMatanzas 32 |   8.1% | 31/384 | avg 2s/file | ETA 22:33:57 | ~10m58s remaining\nMatanzas 32 |   8.6% | 33/384 | avg 2s/file | ETA 22:33:58 | ~10m56s remaining\nMatanzas 32 |   9.1% | 35/384 | avg 2s/file | ETA 22:33:58 | ~10m52s remaining\nMatanzas 32 |   9.6% | 37/384 | avg 2s/file | ETA 22:33:57 | ~10m47s remaining\nMatanzas 32 |   9.9% | 38/384 | avg 2s/file | ETA 22:34:00 | ~10m48s remaining\nMatanzas 32 |  10.4% | 40/384 | avg 2s/file | ETA 22:34:01 | ~10m45s remaining\nMatanzas 32 |  10.9% | 42/384 | avg 2s/file | ETA 22:34:01 | ~10m42s remaining\nMatanzas 32 |  11.5% | 44/384 | avg 2s/file | ETA 22:34:02 | ~10m39s remaining\nMatanzas 32 |  12.0% | 46/384 | avg 2s/file | ETA 22:34:03 | ~10m35s remaining\nMatanzas 32 |  12.5% | 48/384 | avg 2s/file | ETA 22:34:02 | ~10m31s remaining\nMatanzas 32 |  13.0% | 50/384 | avg 2s/file | ETA 22:34:02 | ~10m27s remaining\nMatanzas 32 |  13.5% | 52/384 | avg 2s/file | ETA 22:34:03 | ~10m24s remaining\nMatanzas 32 |  14.1% | 54/384 | avg 2s/file | ETA 22:34:04 | ~10m21s remaining\nMatanzas 32 |  14.6% | 56/384 | avg 2s/file | ETA 22:34:05 | ~10m18s remaining\nMatanzas 32 |  15.1% | 58/384 | avg 2s/file | ETA 22:34:04 | ~10m14s remaining\nMatanzas 32 |  15.6% | 60/384 | avg 2s/file | ETA 22:34:05 | ~10m11s remaining\nMatanzas 32 |  16.1% | 62/384 | avg 2s/file | ETA 22:34:07 | ~10m09s remaining\nMatanzas 32 |  16.7% | 64/384 | avg 2s/file | ETA 22:34:08 | ~10m06s remaining\nMatanzas 32 |  17.2% | 66/384 | avg 2s/file | ETA 22:34:08 | ~10m02s remaining\nMatanzas 32 |  17.7% | 68/384 | avg 2s/file | ETA 22:34:08 | ~9m58s remaining\nMatanzas 32 |  18.0% | 69/384 | avg 2s/file | ETA 22:34:10 | ~9m58s remaining\nMatanzas 32 |  18.5% | 71/384 | avg 2s/file | ETA 22:34:10 | ~9m54s remaining\nMatanzas 32 |  19.0% | 73/384 | avg 2s/file | ETA 22:34:11 | ~9m51s remaining\nMatanzas 32 |  19.3% | 74/384 | avg 2s/file | ETA 22:34:11 | ~9m50s remaining\nMatanzas 32 |  19.8% | 76/384 | avg 2s/file | ETA 22:34:11 | ~9m46s remaining\nMatanzas 32 |  20.3% | 78/384 | avg 2s/file | ETA 22:34:10 | ~9m41s remaining\nMatanzas 32 |  20.8% | 80/384 | avg 2s/file | ETA 22:34:10 | ~9m37s remaining\nMatanzas 32 |  21.4% | 82/384 | avg 2s/file | ETA 22:34:10 | ~9m33s remaining\nMatanzas 32 |  21.9% | 84/384 | avg 2s/file | ETA 22:34:10 | ~9m30s remaining\nMatanzas 32 |  22.4% | 86/384 | avg 2s/file | ETA 22:34:32 | ~9m43s remaining\nMatanzas 32 |  22.9% | 88/384 | avg 2s/file | ETA 22:34:32 | ~9m39s remaining\nMatanzas 32 |  23.4% | 90/384 | avg 2s/file | ETA 22:34:32 | ~9m35s remaining\nMatanzas 32 |  24.0% | 92 ...
# # A tibble: 5 × 4
#   Site           Segments Mean_NDSI SD_NDSI
#   <chr>             <int>     <dbl>   <dbl>
# 1 Las Cruces 26       384     0.750  0.0405
# 2 Matanzas 32         384     0.527  0.134
# 3 San Antonio 38      384    -0.517  0.191
# 4 Ventanas 36         384     0.493  0.140
# 5 Zapallar 34         384     0.449  0.0601
# # A tibble: 10 × 5
#    Site           NDSI_Quadrant Segments Total_Segments Percent_Time
#    <fct>          <chr>            <int>          <int>        <dbl>
#  1 San Antonio 38 (0, 0.5)             2            384        0.521
#  2 San Antonio 38 [-0.5, 0]          181            384       47.1
#  3 San Antonio 38 [-1, -0.5)         201            384       52.3
#  4 Ventanas 36    (0, 0.5)           215            384       56.0
#  5 Ventanas 36    [0.5, 1]           169            384       44.0
#  6 Zapallar 34    (0, 0.5)           305            384       79.4
#  7 Zapallar 34    [0.5, 1]            79            384       20.6
#  8 Las Cruces 26  [0.5, 1]           384            384      100
#  9 Matanzas 32    (0, 0.5)           111            384       28.9
# 10 Matanzas 32    [0.5, 1]           273            384       71.1
# Found 15612 files in San Antonio 38 (searching recursively, case-insensitive)
# Found 15185 files in Ventanas 36 (searching recursively, case-insensitive)
# Found 15164 files in Zapallar 34 (searching recursively, case-insensitive)
# Found 18496 files in Las Cruces 26 (searching recursively, case-insensitive)
# Found 17707 files in Matanzas 32 (searching recursively, case-insensitive)
# Saved to: /Users/Rodrigo/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/NDSIResults/ndsi_casestudies_20251121-20251124_anthro_1000-2000_bio_2000-3000.csv
