# %% [markdown]
# <a href="https://colab.research.google.com/github/rodgpt/MAR_FUTURA/blob/main/NDSI_Sites_Comparisson_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This code compares the NDSI and bio-anthro energy for different cases. It allows to set a date range

# %%
#This cell mounts the google drive and install packages to be able to run the rest in R, because the whole runtime is in phyton

from google.colab import drive
drive.mount('/content/drive')
# !pip install rpy2
# %load_ext rpy2.ipython

# %%
# %%R
#
# install.packages("tuneR")
# install.packages("seewave")
# install.packages("dplyr")
# install.packages("purrr")
# install.packages("ggplot2")
# install.packages("scales")
# install.packages("lubridate")
# install.packages("tidyr")
# install.packages("soundecology")
# install.packages("beepr")
#
# library(tuneR)
# library(seewave)
# library(dplyr)
# library(purrr)
# library(ggplot2)
# library(scales)
# library(lubridate)
# library(tidyr)
# library(soundecology)
# library(beepr)

# %%
# %%R
#
# #For running locally (Rod)
# #dirs_sites <- list(
# #  "San Antonio 28" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/San Antonio/28",
# #  "Ventanas 39" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Ventanas/20-10-25/39/Untitled",
# #  "Zapallar 32" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Zapallar/20-10-25/32"
# #)
#
# #For running in Colab
# dirs_sites <- list(
#   "San Antonio 28" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/San Antonio/28",
#   "Ventanas 39" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Ventanas/20-10-25/39/Untitled",
#   "Zapallar 32" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Zapallar/20-10-25/32",
#   "Las Cruces 41" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/LasCruces/20-10-25/41"
# )
#
# segment_sec <- 250
# anthro_band <- c(1000, 2000)
# bio_band    <- c(2000, 3000) #c(2000, 3000)
# tz <- "UTC"
# analysis_duration <- NA
# files_per_folder <- NA
# output_csv <- "ndsi_casestudies_results.csv"
#
# start_date <- as.POSIXct("2025-10-21 00:00:00", tz = tz)
# end_date   <- as.POSIXct("2025-11-05 23:59:59", tz = tz)
#
# extract_datetime <- function(filename) {
#   dt_str <- sub("^(?:ST_\\d+_)?(\\d{8}_\\d{6})\\.WAV$", "\\1", basename(filename), ignore.case = TRUE)
#   as.POSIXct(dt_str, format = "%Y%m%d_%H%M%S", tz = tz)
# }
#
# calculate_ndsi <- function(wave_obj) {
#   nd <- ndsi(
#     wave_obj,
#     anthro_min = anthro_band[1], anthro_max = anthro_band[2],
#     bio_min    = bio_band[1],    bio_max    = bio_band[2]
#   )
#
#   samples <- wave_obj@left
#   sample_rate <- wave_obj@samp.rate
#   n <- length(samples)
#
#   fft_result <- fft(samples)
#   power_spectrum <- Mod(fft_result[1:(n/2)])^2 / n^2
#   freqs_hz <- (0:(n/2 - 1)) * (sample_rate / as.double(n))
#
#   anthro_indices <- which(freqs_hz >= anthro_band[1] & freqs_hz <= anthro_band[2])
#   anthro_energy <- sum(power_spectrum[anthro_indices])
#
#   bio_indices <- which(freqs_hz >= bio_band[1] & freqs_hz <= bio_band[2])
#   bio_energy <- sum(power_spectrum[bio_indices])
#
#   list(ndsi = nd$ndsi_left, anthro_energy = anthro_energy, bio_energy = bio_energy)
# }
#
# process_site <- function(directory, label) {
#   files <- list.files(directory, pattern = "\\.wav$", full.names = TRUE, recursive = TRUE, ignore.case = TRUE)
#   message("Found ", length(files), " files in ", label, " (searching recursively, case-insensitive)")
#   files <- sort(files)
#
#   # Pre-compute datetimes from filenames and filter files to those near the date window
#   if (length(files) == 0) {
#     file_dt <- tibble(
#       filepath = character(),
#       start_dt = as.POSIXct(character(), tz = tz)
#     )
#   } else {
#     file_dt <- purrr::map_df(files, ~tibble(
#       filepath = .x,
#       start_dt = extract_datetime(.x)
#     ))
#   }
#
#   if (nrow(file_dt) > 0) { # Only filter if there are rows to filter
#     if (!is.na(start_date)) {
#       # keep files that start not earlier than (start_date - segment_sec) to allow boundary segments
#       file_dt <- dplyr::filter(file_dt, start_dt >= (start_date - segment_sec))
#     }
#     if (!is.na(end_date)) {
#       file_dt <- dplyr::filter(file_dt, start_dt <= end_date)
#     }
#   }
#
#   file_dt <- dplyr::arrange(file_dt, start_dt)
#   files <- file_dt$filepath
#
#   if (!is.na(files_per_folder)) {
#     files <- head(files, files_per_folder)
#   }
#
#   results <- list()
#
#   for (fp in files) {
#     message("Reading: ", fp)
#     start_dt <- extract_datetime(fp)
#
#     wav <- tryCatch(readWave(fp), error = function(e) {
#       warning("Skipping unreadable file: ", fp)
#       return(NULL)
#     })
#     if (is.null(wav)) next
#
#     dur_sec <- length(wav@left) / wav@samp.rate
#     max_start <- max(0, dur_sec - segment_sec)
#     starts <- seq(0, max_start, by = segment_sec)
#
#     for (st in starts) {
#       segment_time <- start_dt + st
#
#       if (!is.na(start_date) && segment_time < start_date) {
#         next
#       }
#       if (!is.na(end_date) && segment_time > end_date) {
#         break
#       }
#
#       seg <- tryCatch(
#         extractWave(wav, from = st, to = st + segment_sec, xunit = "time"),
#         error = function(e) return(NULL)
#       )
#       if (is.null(seg)) next
#
#       ndsi_res <- calculate_ndsi(seg)
#
#       results[[length(results) + 1]] <- tibble(
#         Site = label,
#         Time = segment_time,
#         NDSI = ndsi_res$ndsi,
#         Anthro_Energy = ndsi_res$anthro_energy,
#         Bio_Energy = ndsi_res$bio_energy
#       )
#     }
#   }
#
#   if (length(results) == 0) {
#     return(tibble(
#       Site = character(),
#       Time = as.POSIXct(character()),
#       NDSI = numeric(),
#       Anthro_Energy = numeric(),
#       Bio_Energy = numeric()
#     ))
#   }
#   bind_rows(results)
# }
#
# all_results <- bind_rows(
#   lapply(names(dirs_sites), function(label) {
#     process_site(dirs_sites[[label]], label)
#   })
# )
#
# if (!exists("all_results") || nrow(all_results) == 0) {
#   stop("No WAV files found in the provided directories and date range. Please verify the paths in `dirs_sites` and the date filters.")
# }
#
# write.csv(all_results, output_csv, row.names = FALSE)
# message("Saved to: ", output_csv)
#
# summary_stats <- all_results %>%
#   group_by(Site) %>%
#   summarize(
#     Segments  = n(),
#     Mean_NDSI = mean(NDSI, na.rm = TRUE),
#     SD_NDSI   = sd(NDSI, na.rm = TRUE),
#     Mean_Anthro_Energy = mean(Anthro_Energy, na.rm = TRUE),
#     SD_Anthro_Energy = sd(Anthro_Energy, na.rm = TRUE),
#     Mean_Bio_Energy = mean(Bio_Energy, na.rm = TRUE),
#     SD_Bio_Energy = sd(Bio_Energy, na.rm = TRUE)
#   )
# print(summary_stats)
#
# plot_data <- all_results
#
# plot_data$Site <- factor(plot_data$Site, levels = names(dirs_sites))
#
# ## NDSI time-series plot
# p_ndsi <- ggplot(plot_data, aes(x = Time, y = NDSI, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "NDSI Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "NDSI"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_ndsi)
#
# ## Anthropogenic energy time-series plot
# p_anthro <- ggplot(plot_data, aes(x = Time, y = Anthro_Energy, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "Anthropogenic Energy Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "Anthropogenic Energy (arbitrary units)"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_anthro)
#
# ## Biophonic energy time-series plot
# p_bio <- ggplot(plot_data, aes(x = Time, y = Bio_Energy, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "Biophonic Energy Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "Biophonic Energy (arbitrary units)"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_bio)
#
# ## NDSI quadrant table (percentage of time per site in each quadrant)
# ndsi_quadrant_table <- plot_data %>%
#   mutate(
#     NDSI_Quadrant = case_when(
#       NDSI >= 0.5  & NDSI <= 1   ~ "[0.5, 1]",
#       NDSI >  0    & NDSI <  0.5 ~ "(0, 0.5)",
#       NDSI >= -0.5 & NDSI <= 0   ~ "[-0.5, 0]",
#       NDSI >= -1   & NDSI < -0.5 ~ "[-1, -0.5)",
#       TRUE ~ NA_character_
#     )
#   ) %>%
#   filter(!is.na(NDSI_Quadrant)) %>%
#   group_by(Site, NDSI_Quadrant) %>%
#   summarise(
#     Segments = n(),
#     .groups = "drop_last"
#   ) %>%
#   mutate(
#     Total_Segments = sum(Segments),
#     Percent_Time = 100 * Segments / Total_Segments
#   ) %>%
#   ungroup()
#
# print(ndsi_quadrant_table)
#
# beepr::beep(3)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05802269
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08368766
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.124197
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1153849
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07527734
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05688233
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07384676
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06949646
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06017264
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06061616
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08877709
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1182234
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.102541
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08245778
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1125671
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08866399
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07514001
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07714167
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04332081
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02807548
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05049911
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06009999
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07990961
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1122405
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1237648
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1206571
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09351496
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0988107
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09917574
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1002608
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09129062
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1100128
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03502503
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1184893
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.101566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1259149
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1089003
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09670736
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0922733
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07753916
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08483406
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08302867
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06884292
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09330623
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09976171
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09615784
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.081574
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07893677
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07902114
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05928132
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08488737
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06380986
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05789556
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08570077
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07453575
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1008987
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06312551
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05513432
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06539819
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08400935
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08537896
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1022743
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1135087
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1105555
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09556112
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1346148
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1008809
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09299344
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03264212
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06259523
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07878664
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0527451
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07875593
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0988452
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07882557
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03769433
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09075388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07769262
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08475456
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06358463
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07726731
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.100447
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08363392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0918685
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1267679
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07393057
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09168348
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1361037
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1292936
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1446259
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09838811
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1211084
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1115034
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1098334
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1232593
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1168144
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1052771
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1200104
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1180705
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.103708
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1045083
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09652894
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09993534
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07076029
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1007445
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1351905
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09003969
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1087012
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1110408
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1067448
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.072215
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1050842
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1004813
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.100983
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1200516
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1266068
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1103645
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1233045
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1141442
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1279967
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1179197
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.153463
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1425389
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09926928
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06355297
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08101268
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08274412
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09091202
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06952896
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08398495
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06072197
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1022479
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0834644
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08964957
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1078131
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0279304
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03752041
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03318815
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07365929
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09935956
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08758747
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1138457
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1160823
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07696624
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1011008
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.007446236
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01227974
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03889353
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08249092
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06831614
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07689676
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08583986
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06318423
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07929732
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07645125
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07815965
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07183134
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04357859
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07650801
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05181974
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07562317
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06421532
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05982188
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03937493
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01259399
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04529797
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06453996
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06739088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04747085
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01097676
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02229446
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03496985
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05254193
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06647769
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08866128
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06261189
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05642273
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06553274
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05208091
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08987823
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02323322
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04708055
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04434866
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007418289
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00492516
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02047344
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06820504
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04522049
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03532818
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.002980966
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02098466
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02180368
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05043035
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03166404
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01242199
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04619804
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03365384
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0555885
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01743028
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02385557
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.001910555
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03565924
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01561909
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03908424
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05794698
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04936342
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02955882
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04603242
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07765809
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01043967
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02740726
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01763471
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03322211
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07550756
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07427705
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06755387
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02664705
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.005091316
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05897413
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04741548
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04506928
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02272968
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05455653
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0350011
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04280141
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05453309
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02096161
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02900752
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01787516
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04988823
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03889002
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007984694
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02127649
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02851347
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01332566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04897252
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01525372
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02623335
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.008316286
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02378527
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01652926
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.005701016
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0206897
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02233859
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006471352
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001957932
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03489888
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008974537
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03874676
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01735297
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004301394
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004480204
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0241831
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03775572
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05346148
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07201926
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02693583
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04041632
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03779301
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03189577
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04620102
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04230968
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05347547
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08241851
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08745159
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1110207
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1068062
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08563701
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06581553
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05398037
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0781612
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06665013
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07173735
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07035302
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0603713
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07618259
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04456423
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1197366
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09578067
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05568411
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1078837
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07756459
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08317728
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07376351
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09002251
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04091202
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05925139
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06155846
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04485664
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08815648
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06532734
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05580691
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05738342
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02827561
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0163223
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0008719427
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008341496
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02359094
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02079308
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003376519
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01817359
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02119081
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007115113
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01896976
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.006671773
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.002040895
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01976299
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0168455
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04656398
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01236547
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02464666
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01037692
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02872986
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.043243
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01406515
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0006374309
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01444074
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01463077
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01895675
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004667844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03347551
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003010173
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02505437
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01182649
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02150115
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02843688
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01256494
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03009709
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001082616
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03178538
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01656893
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01990761
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0002784121
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01560522
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01671794
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05720984
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03361951
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03761556
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03913862
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04614016
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06039108
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04708388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03321057
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05733372
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01748441
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02470787
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08503534
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02468191
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02066565
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03450238
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0004114811
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02234904
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02563027
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02600633
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06655882
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03193067
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01584018
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03747364
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.008412029
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01508231
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04340553
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009040097
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.009681284
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01778795
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02812513
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01570157
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009533747
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02164535
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01976081
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00156437
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04882787
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02173218
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01568701
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01094317
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03228482
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01886562
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01963776
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01163075
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02448672
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0490944
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04407894
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05042198
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03062691
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03324917
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02824128
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008716696
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01953884
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02278339
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01342516
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00451113
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02536216
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04378392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05611207
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07395672
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02451742
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.2831048
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01835982
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03218937
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00859053
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06617679
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06600754
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05105813
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001221707
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003689167
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05515253
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04347459
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03913783
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02181478
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04387838
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05217088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0264977
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02957868
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02382319
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03613791
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02153637
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
# ...
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007991677
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04387561
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06178211
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03827702
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02566208
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02815275
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01715308
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07197481
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03540751
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05176722
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07670844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03337387
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05038921
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00813571
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.006227653
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04371385
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03662679
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.101067
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03997684
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06193566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01181349
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01398951
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00607313
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01684236
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03060273
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02986152
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02210228
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02036803
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008957928
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009763948
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01334323
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001860924
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01070196
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006081036
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02256291
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06289791
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04065171
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007626474
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00870983
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02701629
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09189805
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02156311
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01172566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.023024
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.008681
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02451041
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03516014
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01242739
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06852014
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1382217
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1367997
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08711799
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02762358
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.052226
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02840271
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02219422
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02787595
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02525969
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0020151
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03090343
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.005586281
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01792775
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02934717
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03125281
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0350638
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0392831
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01901564
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0320392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02128615
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02249743
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01744307
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01354031
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02398429
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01263605
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01421186
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007379993
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01310545
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02010781
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01680732
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03329688
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0238349
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01644201
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006100329
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0242801
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03850535
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004344268
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05200011
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0261687
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04292285
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04652451
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03382865
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02925704
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02670844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03148905
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04970049
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05266478
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04475089
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08118088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05695716
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04988058
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03225413
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02369255
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03368056
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04476646
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03225546
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06498236
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09606136
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07091379
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05005925
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04389613
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01188643
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07023295
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06273229
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08151441
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07018142
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1044249
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04956839
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04137107
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03349954
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05636388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03156858
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03455592
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05385726
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01067007
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007103666
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01748685
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0188782
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02436809
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03124003
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03958228
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05059083
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04983878
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0164923
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01213012
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01193229
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03674168
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02749681
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0528392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
