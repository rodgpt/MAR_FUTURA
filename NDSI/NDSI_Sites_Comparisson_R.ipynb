# %% [markdown]
# <a href="https://colab.research.google.com/github/rodgpt/MAR_FUTURA/blob/main/NDSI/NDSI_Sites_Comparisson_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This code compares the NDSI and bio-anthro energy for different cases. It allows to set a date range

# %%
#This cell mounts the google drive and install packages to be able to run the rest in R, because the whole runtime is in phyton

from google.colab import drive
drive.mount('/content/drive')
# !pip install rpy2
# %load_ext rpy2.ipython

#Prueba de cambio ariel v3

# %%
# %%R
#
# install.packages("tuneR")
# install.packages("seewave")
# install.packages("dplyr")
# install.packages("purrr")
# install.packages("ggplot2")
# install.packages("scales")
# install.packages("lubridate")
# install.packages("tidyr")
# install.packages("soundecology")
# install.packages("beepr")
#
# library(tuneR)
# library(seewave)
# library(dplyr)
# library(purrr)
# library(ggplot2)
# library(scales)
# library(lubridate)
# library(tidyr)
# library(soundecology)
# library(beepr)

# %%
# %%R
#
# #For running locally (Rod)
# #dirs_sites <- list(
# #  "San Antonio 28" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/San Antonio/28",
# #  "Ventanas 39" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Ventanas/20-10-25/39/Untitled",
# #  "Zapallar 32" = "/Users/rod/Library/CloudStorage/GoogleDrive-royanedel@marfutura.org/Unidades compartidas/MAR FUTURA/Hydrophones/Zapallar/20-10-25/32"
# #)
#
# #For running in Colab
# dirs_sites <- list(
#   "San Antonio 28" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/San Antonio/28",
#   "Ventanas 39" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Ventanas/20-10-25/39/Untitled",
#   "Zapallar 32" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/Zapallar/20-10-25/32",
#   "Las Cruces 41" = "/content/drive/Shareddrives/MAR FUTURA/Hydrophones/LasCruces/20-10-25/41"
# )
#
# segment_sec <- 250
# anthro_band <- c(1000, 2000)
# bio_band    <- c(2000, 3000) #c(2000, 3000)
# tz <- "UTC"
# analysis_duration <- NA
# files_per_folder <- NA
# output_csv <- "ndsi_casestudies_results.csv"
#
# start_date <- as.POSIXct("2025-10-21 00:00:00", tz = tz)
# end_date   <- as.POSIXct("2025-11-05 23:59:59", tz = tz)
#
# extract_datetime <- function(filename) {
#   dt_str <- sub("^(?:ST_\\d+_)?(\\d{8}_\\d{6})\\.WAV$", "\\1", basename(filename), ignore.case = TRUE)
#   as.POSIXct(dt_str, format = "%Y%m%d_%H%M%S", tz = tz)
# }
#
# calculate_ndsi <- function(wave_obj) {
#   nd <- ndsi(
#     wave_obj,
#     anthro_min = anthro_band[1], anthro_max = anthro_band[2],
#     bio_min    = bio_band[1],    bio_max    = bio_band[2]
#   )
#
#   samples <- wave_obj@left
#   sample_rate <- wave_obj@samp.rate
#   n <- length(samples)
#
#   fft_result <- fft(samples)
#   power_spectrum <- Mod(fft_result[1:(n/2)])^2 / n^2
#   freqs_hz <- (0:(n/2 - 1)) * (sample_rate / as.double(n))
#
#   anthro_indices <- which(freqs_hz >= anthro_band[1] & freqs_hz <= anthro_band[2])
#   anthro_energy <- sum(power_spectrum[anthro_indices])
#
#   bio_indices <- which(freqs_hz >= bio_band[1] & freqs_hz <= bio_band[2])
#   bio_energy <- sum(power_spectrum[bio_indices])
#
#   list(ndsi = nd$ndsi_left, anthro_energy = anthro_energy, bio_energy = bio_energy)
# }
#
# process_site <- function(directory, label) {
#   files <- list.files(directory, pattern = "\\.wav$", full.names = TRUE, recursive = TRUE, ignore.case = TRUE)
#   message("Found ", length(files), " files in ", label, " (searching recursively, case-insensitive)")
#   files <- sort(files)
#
#   # Pre-compute datetimes from filenames and filter files to those near the date window
#   if (length(files) == 0) {
#     file_dt <- tibble(
#       filepath = character(),
#       start_dt = as.POSIXct(character(), tz = tz)
#     )
#   } else {
#     file_dt <- purrr::map_df(files, ~tibble(
#       filepath = .x,
#       start_dt = extract_datetime(.x)
#     ))
#   }
#
#   if (nrow(file_dt) > 0) { # Only filter if there are rows to filter
#     if (!is.na(start_date)) {
#       # keep files that start not earlier than (start_date - segment_sec) to allow boundary segments
#       file_dt <- dplyr::filter(file_dt, start_dt >= (start_date - segment_sec))
#     }
#     if (!is.na(end_date)) {
#       file_dt <- dplyr::filter(file_dt, start_dt <= end_date)
#     }
#   }
#
#   file_dt <- dplyr::arrange(file_dt, start_dt)
#   files <- file_dt$filepath
#
#   if (!is.na(files_per_folder)) {
#     files <- head(files, files_per_folder)
#   }
#
#   results <- list()
#
#   for (fp in files) {
#     message("Reading: ", fp)
#     start_dt <- extract_datetime(fp)
#
#     wav <- tryCatch(readWave(fp), error = function(e) {
#       warning("Skipping unreadable file: ", fp)
#       return(NULL)
#     })
#     if (is.null(wav)) next
#
#     dur_sec <- length(wav@left) / wav@samp.rate
#     max_start <- max(0, dur_sec - segment_sec)
#     starts <- seq(0, max_start, by = segment_sec)
#
#     for (st in starts) {
#       segment_time <- start_dt + st
#
#       if (!is.na(start_date) && segment_time < start_date) {
#         next
#       }
#       if (!is.na(end_date) && segment_time > end_date) {
#         break
#       }
#
#       seg <- tryCatch(
#         extractWave(wav, from = st, to = st + segment_sec, xunit = "time"),
#         error = function(e) return(NULL)
#       )
#       if (is.null(seg)) next
#
#       ndsi_res <- calculate_ndsi(seg)
#
#       results[[length(results) + 1]] <- tibble(
#         Site = label,
#         Time = segment_time,
#         NDSI = ndsi_res$ndsi,
#         Anthro_Energy = ndsi_res$anthro_energy,
#         Bio_Energy = ndsi_res$bio_energy
#       )
#     }
#   }
#
#   if (length(results) == 0) {
#     return(tibble(
#       Site = character(),
#       Time = as.POSIXct(character()),
#       NDSI = numeric(),
#       Anthro_Energy = numeric(),
#       Bio_Energy = numeric()
#     ))
#   }
#   bind_rows(results)
# }
#
# all_results <- bind_rows(
#   lapply(names(dirs_sites), function(label) {
#     process_site(dirs_sites[[label]], label)
#   })
# )
#
# if (!exists("all_results") || nrow(all_results) == 0) {
#   stop("No WAV files found in the provided directories and date range. Please verify the paths in `dirs_sites` and the date filters.")
# }
#
# write.csv(all_results, output_csv, row.names = FALSE)
# message("Saved to: ", output_csv)
#
# summary_stats <- all_results %>%
#   group_by(Site) %>%
#   summarize(
#     Segments  = n(),
#     Mean_NDSI = mean(NDSI, na.rm = TRUE),
#     SD_NDSI   = sd(NDSI, na.rm = TRUE),
#     Mean_Anthro_Energy = mean(Anthro_Energy, na.rm = TRUE),
#     SD_Anthro_Energy = sd(Anthro_Energy, na.rm = TRUE),
#     Mean_Bio_Energy = mean(Bio_Energy, na.rm = TRUE),
#     SD_Bio_Energy = sd(Bio_Energy, na.rm = TRUE)
#   )
# print(summary_stats)
#
# plot_data <- all_results
#
# plot_data$Site <- factor(plot_data$Site, levels = names(dirs_sites))
#
# ## NDSI time-series plot
# p_ndsi <- ggplot(plot_data, aes(x = Time, y = NDSI, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "NDSI Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "NDSI"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_ndsi)
#
# ## Anthropogenic energy time-series plot
# p_anthro <- ggplot(plot_data, aes(x = Time, y = Anthro_Energy, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "Anthropogenic Energy Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "Anthropogenic Energy (arbitrary units)"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_anthro)
#
# ## Biophonic energy time-series plot
# p_bio <- ggplot(plot_data, aes(x = Time, y = Bio_Energy, color = Site)) +
#   geom_line(size = 0.8) +
#   facet_wrap(~Site, ncol = 1, scales = "free_x") +
#   scale_x_datetime(
#     date_labels = "%d-%b %H:%M",
#     date_breaks = "2 hour",
#     expand = expansion(mult = c(0.01, 0.01))
#   ) +
#   labs(
#     title = "Biophonic Energy Over Time for Case Study Sites",
#     x = "Date-Time",
#     y = "Biophonic Energy (arbitrary units)"
#   ) +
#   theme_minimal() +
#   theme(
#     legend.position = "none",
#     plot.title = element_text(face = "bold", size = 14),
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1,
#       vjust = 1,
#       size = 6,
#       margin = margin(t = 5)
#     ),
#     strip.text = element_text(face = "bold")
#   )
#
# print(p_bio)
#
# ## NDSI quadrant table (percentage of time per site in each quadrant)
# ndsi_quadrant_table <- plot_data %>%
#   mutate(
#     NDSI_Quadrant = case_when(
#       NDSI >= 0.5  & NDSI <= 1   ~ "[0.5, 1]",
#       NDSI >  0    & NDSI <  0.5 ~ "(0, 0.5)",
#       NDSI >= -0.5 & NDSI <= 0   ~ "[-0.5, 0]",
#       NDSI >= -1   & NDSI < -0.5 ~ "[-1, -0.5)",
#       TRUE ~ NA_character_
#     )
#   ) %>%
#   filter(!is.na(NDSI_Quadrant)) %>%
#   group_by(Site, NDSI_Quadrant) %>%
#   summarise(
#     Segments = n(),
#     .groups = "drop_last"
#   ) %>%
#   mutate(
#     Total_Segments = sum(Segments),
#     Percent_Time = 100 * Segments / Total_Segments
#   ) %>%
#   ungroup()
#
# print(ndsi_quadrant_table)
#
# beepr::beep(3)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   Normalized Difference Soundscape Index: 0.008455041
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03211947
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0181787
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00461391
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02476219
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03079688
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04485088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01273758
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007991677
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04387561
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06178211
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03827702
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02566208
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02815275
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01715308
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07197481
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03540751
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05176722
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07670844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03337387
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05038921
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00813571
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.006227653
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04371385
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03662679
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.101067
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03997684
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06193566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01181349
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01398951
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00607313
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01684236
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03060273
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02986152
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02210228
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02036803
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008957928
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009763948
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01334323
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001860924
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01070196
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006081036
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02256291
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06289791
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04065171
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007626474
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00870983
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02701629
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09189805
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02156311
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01172566
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.023024
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.008681
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02451041
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03516014
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01242739
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06852014
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1382217
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1367997
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08711799
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02762358
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.052226
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02840271
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02219422
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02787595
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02525969
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0020151
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03090343
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.005586281
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01792775
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02934717
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03125281
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0350638
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0392831
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01901564
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0320392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02128615
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02249743
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01744307
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01354031
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02398429
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01263605
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01421186
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007379993
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01310545
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02010781
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01680732
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03329688
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0238349
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01644201
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006100329
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0242801
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03850535
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004344268
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05200011
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0261687
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04292285
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04652451
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03382865
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02925704
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02670844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03148905
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04970049
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05266478
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04475089
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08118088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05695716
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04988058
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03225413
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02369255
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03368056
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04476646
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03225546
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06498236
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09606136
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07091379
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05005925
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04389613
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01188643
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07023295
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06273229
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08151441
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07018142
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1044249
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04956839
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04137107
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03349954
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05636388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03156858
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03455592
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05385726
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01067007
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007103666
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01748685
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0188782
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02436809
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03124003
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03958228
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05059083
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04983878
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0164923
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01213012
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01193229
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03674168
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02749681
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0528392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04973191
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01505202
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01403944
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01598405
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.002193309
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01243183
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01292808
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03333064
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009614528
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01353803
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02597629
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02793233
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02089403
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02797469
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02470327
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03073146
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01990852
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01545884
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02469018
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02071524
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02355538
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.006767479
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02751512
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03616782
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01418815
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02505494
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04124461
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03178078
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05371141
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0303708
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03074103
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0548398
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04372652
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03639283
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07568023
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04651632
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0009325191
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03032079
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03925414
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03476248
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04346538
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0609553
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05204834
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03673808
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0261525
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01661534
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02791287
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06677227
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06377142
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07210927
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06063396
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.10443
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1053194
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1202651
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09743298
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05123438
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04594028
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06498173
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07585146
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04735632
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06776197
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06909641
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07842286
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07978388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09976049
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09920886
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0688921
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05169109
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04028676
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05819368
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01790677
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001359488
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03280819
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0135045
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01794134
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03522252
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05299191
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03999933
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04551115
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04492721
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04375423
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06951754
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03052605
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.001467223
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0006557281
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007905297
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02168803
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02401445
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01682778
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01063458
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00974827
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01801868
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.004761504
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003185995
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.008277469
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03030671
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04284854
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01688678
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.00428413
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02612423
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.001244248
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.006068082
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.003589231
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.007192557
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02320024
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02881542
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0008582251
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.004065629
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01210841
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00712761
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01026117
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01323576
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01106486
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004672403
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0534332
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02968494
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01787538
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01256976
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04030054
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01405731
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.004547066
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02819093
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03408633
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.002945123
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07640331
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04269722
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07519633
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07920711
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02838377
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04487346
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02229669
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02178068
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04406449
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03625773
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0430688
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06205816
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04540591
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04955017
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03977646
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07490806
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06361791
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01534091
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05235409
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05418329
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04923777
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08289844
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07487649
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05687896
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05709861
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06895441
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05226943
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05577788
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05136456
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03748124
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03780888
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01410924
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01913645
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06307904
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05497732
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05181925
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06006618
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03922782
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04505504
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04096598
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03603092
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07550728
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06328486
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06875946
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07472617
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09333276
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09271097
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05645948
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04425591
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08522511
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08568717
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08200926
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09904052
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09811942
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03414178
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.004547264
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02048452
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01996597
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.001307735
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03822257
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.004161644
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03215567
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05456101
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04588887
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02722315
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06939624
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05135895
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04360012
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06923775
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08248093
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05608661
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06268196
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01888959
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04928369
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0361223
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0552917
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07079667
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05915372
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05836243
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07086305
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04598853
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06977819
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05766678
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04305266
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04395553
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06175134
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06552969
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07040307
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06692617
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07548821
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06128606
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06085385
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.03292962
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02377302
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01095437
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.038671
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.04814386
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02385157
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.05169702
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.06393944
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07705283
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08812445
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0848119
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08304403
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1054017
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09785816
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.07354899
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0636774
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09607157
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1063664
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1115872
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1187479
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09305425
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08809835
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1127372
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09851739
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1289467
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1124199
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08090725
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1214624
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.126687
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1044853
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1260174
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1327342
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.09164682
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01777119
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02578086
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0518536
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0001982078
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03412507
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01692697
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02751941
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05209337
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05166392
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07537422
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01634088
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02908502
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03610835
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03119633
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.004509305
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.006691308
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.02719876
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.009999328
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03925626
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0009867058
#
#
#  This is a mono file.
#
# ...
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03601517
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.002000493
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03988598
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07605857
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08398367
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06829914
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07350461
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1104123
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1110391
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1187585
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1020421
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1311883
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1005325
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09970114
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07923257
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09939614
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1070681
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1214177
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09525776
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1392517
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09999779
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09423013
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.100534
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1137798
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09203394
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1088571
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1079867
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1047251
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1068343
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.137699
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.146434
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1439951
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1086227
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07285905
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1214117
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1217401
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1163006
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04253388
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.1899107
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.08100485
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01449803
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0004769937
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1267525
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1365234
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1221941
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1388442
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1135094
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1268151
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1018819
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08738646
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09048227
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07986929
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.030637
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01874201
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0356464
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07588489
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04848431
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05767118
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05726098
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09203115
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.115287
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1019326
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08130308
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06155208
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06794853
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09192732
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0759744
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08004224
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08546846
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0899433
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1289491
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09053546
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.09314864
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06239255
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07942531
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07359295
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0503184
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07004818
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01567618
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02844293
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04534659
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05634343
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0256584
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05056816
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01846456
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03664649
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06871209
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03252689
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02486171
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0342923
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06913493
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06953508
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06777544
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07171061
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01908409
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02856916
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05266089
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04183748
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05409139
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04402642
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.08708527
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04906275
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03058244
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06575753
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05235242
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02617487
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05679152
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.001490906
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003227627
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.01070945
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.005919998
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02000022
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0336303
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02284917
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03391441
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03991377
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04809644
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.0002238866
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.06226365
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01347434
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03110298
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.002993617
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05264195
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04287533
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.02017511
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.00387282
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.0179908
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: -0.001920301
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.04920379
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.03772563
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1450668
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.07859635
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.01702357
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05668422
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.003014041
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.005176158
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.05064628
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1301294
#
#
#  This is a mono file.
#
#  Calculating index. Please wait...
#
#   Normalized Difference Soundscape Index: 0.1644002
